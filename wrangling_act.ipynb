# %%
import pandas as pd
import numpy as np
import json
import tweepy
import requests
import os
import re
import datetime as dt
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# # Gathering

# %%
# load the twitter-archive-enhanced csv file that was downloaded manually
archive_df = pd.read_csv('twitter-archive-enhanced.csv')

# %%
# get the image-predictions.tsv file from the url
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)
filename = url.split('/')[-1]

if not os.path.isfile(filename):
    with open (filename, 'wb') as f:
        f.write(response.content)
        
image_predictions = pd.read_csv(filename, sep='\t')

# %%
# load the tweepy api 
consumer_key = '**********************'
consumer_secret = '************************'
access_token = '*************************************************'
access_secret = '************************************************'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
# get all the tweepy data from the tweet_id into a json file
errors = []
if not os.path.isfile('tweet_json.txt'):
    with open ('tweet_json.txt', 'w') as f:
        for tweet_id in archive_df['tweet_id']:
            try:
                tweet = api.get_status(tweet_id, wait_on_rate_limit=True,  wait_on_rate_limit_notify=True, tweet_mode = 'extended')
                json.dump(tweet._json, file)
                f.write('\n')
            except Exception as e:
                print("Error on tweet id {}".format(tweet_id) + ";" + str(e))
                errors.append(tweet_id)

# %%
# load the fav_count and retweet_count data from the json file into an api datafram
dict_list = []

with open('tweet_json.txt', 'r') as f:
    for line in f:
        tweet_status = json.loads(line)
        tweet_id = tweet_status['id']
        retweet_count = tweet_status['retweet_count']
        favorite_count = tweet_status['favorite_count']
        dict_list.append({'tweet_id':tweet_id,
                       'retweet_count': retweet_count,
                       'favorite_count': favorite_count})
        
api_df = pd.DataFrame(dict_list)

# %% [markdown]
# ## Assesing

# %% [markdown]
#  ### Visual Assesment

# %%
archive_df
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %%
archive_df.sample(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 892   759447681597108224                    NaN                  NaN
# 1244  711743778164514816                    NaN                  NaN
# 458   817908911860748288                    NaN                  NaN
# 697   786595970293370880                    NaN                  NaN
# 1463  694669722378485760                    NaN                  NaN
#
#                       timestamp  \
# 892   2016-07-30 17:56:51 +0000
# 1244  2016-03-21 02:38:34 +0000
# 458   2017-01-08 01:40:55 +0000
# 697   2016-10-13 15:54:28 +0000
# 1463  2016-02-02 23:52:22 +0000
#
#                                                  source  \
# 892   <a href="http://twitter.com/download/iphone" r...
# 1244  <a href="http://twitter.com/download/iphone" r...
# 458   <a href="http://twitter.com/download/iphone" r...
# 697   <a href="http://twitter.com/download/iphone" r...
# 1463  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
api_df
# Out:
#                 tweet_id  retweet_count  favorite_count
# 0     892420643555336193           7489           35461
# 1     892177421306343426           5557           30693
# 2     891815181378084864           3681           23088
# 3     891689557279858688           7665           38754
# 4     891327558926688256           8267           37032
# ...                  ...            ...             ...
# 2326  666049248165822465             40              96
# 2327  666044226329800704            125             264
# 2328  666033412701032449             39             109
# 2329  666029285002620928             41             119
# 2330  666020888022790149            454            2357
#
# [2331 rows x 3 columns]

# %%
api_df.sample(5)
# Out:
#                 tweet_id  retweet_count  favorite_count
# 1252  709158332880297985            403            1984
# 497   811627233043480576           3070           12754
# 73    878316110768087041           5918               0
# 749   777621514455814149           2479            8670
# 251   842535590457499648           3400           17706

# %%
image_predictions
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %%
image_predictions.sample(5)
# Out:
#                 tweet_id                                          jpg_url  \
# 405   673707060090052608  https://pbs.twimg.com/media/CVl8_EPWoAAcuSC.jpg
# 694   684241637099323392  https://pbs.twimg.com/media/CX7qIcdWcAELJ7N.jpg
# 1875  845677943972139009  https://pbs.twimg.com/media/C7xzmngWkAAAp9C.jpg
# 1328  757400162377592832  https://pbs.twimg.com/media/CoLTbbzXYAElNM6.jpg
# 1174  737322739594330112  https://pbs.twimg.com/media/Cjt_Hm6WsAAjkPG.jpg
#
#       img_num                           p1   p1_conf  p1_dog  \
# 405         1  German_short-haired_pointer  0.935771    True
# 694         1                     Pembroke  0.508498    True
# 1875        1                         chow  0.808681    True
# 1328        1                    seat_belt  0.523926   False
# 1174        1                   guinea_pig  0.148526   False
#
#                        p2   p2_conf  p2_dog                  p3   p3_conf  \
# 405                kelpie  0.022561    True  Labrador_retriever  0.008847
# ...

# %% [markdown]
# ### Programmatic Assessment

# %%
archive_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
archive_df.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
api_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2331 entries, 0 to 2330
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2331 non-null   int64
#  1   retweet_count   2331 non-null   int64
#  2   favorite_count  2331 non-null   int64
# dtypes: int64(3)
# memory usage: 54.8 KB

# %%
api_df.describe()
# Out:
#            tweet_id  retweet_count  favorite_count
# count  2.331000e+03    2331.000000     2331.000000
# mean   7.419079e+17    2634.588160     7410.244959
# std    6.823170e+16    4455.590369    11510.226525
# min    6.660209e+17       1.000000        0.000000
# 25%    6.782670e+17     535.000000     1287.000000
# 50%    7.182469e+17    1231.000000     3219.000000
# 75%    7.986692e+17    3058.500000     9065.500000
# max    8.924206e+17   75693.000000   152918.000000

# %%
image_predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
image_predictions.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %% [markdown]
# ## Tidiness

# %% [markdown]
# archive_df issues:
# - Columns (doggo, fluffer, pupper, puppo) represenets values
# - should include the other two datasets
#
# image_predictions issues:
# - columns p, p_conf, p_dog represents values

# %% [markdown]
# # Quality

# %% [markdown]
# ## archive_df quality assessing

# %%
archive_df.isna().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %%
archive_df.duplicated().sum()
# Out:
# 0

# %%
archive_df[archive_df.rating_numerator == archive_df.rating_numerator.max()]
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 979  749981277374128128                    NaN                  NaN
#
#                      timestamp  \
# 979  2016-07-04 15:00:45 +0000
#
#                                                 source  \
# 979  <a href="https://about.twitter.com/products/tw...
#
#                                                   text  retweeted_status_id  \
# 979  This is Atticus. He's quite simply America af....                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 979                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 979  https://twitter.com/dog_rates/status/749981277...              1776
#
#      rating_denominator     name doggo floofer pupper puppo
# 979                  10  Atticus  None    None   None  None

# %%
archive_df[archive_df.rating_numerator == archive_df.rating_numerator.min()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 315   835152434251116546                    NaN                  NaN
# 1016  746906459439529985           7.468859e+17         4.196984e+09
#
#                       timestamp  \
# 315   2017-02-24 15:40:31 +0000
# 1016  2016-06-26 03:22:31 +0000
#
#                                                  source  \
# 315   <a href="http://twitter.com/download/iphone" r...
# 1016  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 315   When you're so blinded by your systematic plag...                  NaN
# 1016  PUPDATE: can't see any. Even if I could, I cou...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 315                        NaN                        NaN
# 1016                       NaN                        NaN
#
# ...

# %%
archive_df[archive_df.rating_denominator == archive_df.rating_denominator.max()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1120  731156023742988288                    NaN                  NaN
#
#                       timestamp  \
# 1120  2016-05-13 16:15:54 +0000
#
#                                                  source  \
# 1120  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1120  Say hello to this unbelievably well behaved sq...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1120                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1120  https://twitter.com/dog_rates/status/731156023...               204
#
#       rating_denominator  name doggo floofer pupper puppo
# 1120                 170  this  None    None   None  None

# %%
archive_df[archive_df.rating_denominator == archive_df.rating_denominator.min()]
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 313  835246439529840640           8.352460e+17           26259576.0
#
#                      timestamp  \
# 313  2017-02-24 21:54:03 +0000
#
#                                                 source  \
# 313  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 313  @jonnysun @Lin_Manuel ok jomny I know you're e...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp expanded_urls  \
# 313                       NaN                        NaN           NaN
#
#      rating_numerator  rating_denominator  name doggo floofer pupper puppo
# 313               960                   0  None  None    None   None  None

# %%
archive_df[archive_df.rating_denominator != 10]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 313   835246439529840640           8.352460e+17         2.625958e+07
# 342   832088576586297345           8.320875e+17         3.058208e+07
# 433   820690176645140481                    NaN                  NaN
# 516   810984652412424192                    NaN                  NaN
# 784   775096608509886464                    NaN                  NaN
# 902   758467244762497024                    NaN                  NaN
# 1068  740373189193256964                    NaN                  NaN
# 1120  731156023742988288                    NaN                  NaN
# 1165  722974582966214656                    NaN                  NaN
# 1202  716439118184652801                    NaN                  NaN
# 1228  713900603437621249                    NaN                  NaN
# 1254  710658690886586372                    NaN                  NaN
# 1274  709198395643068416                    NaN                  NaN
# ...

# %%
archive_df[archive_df.name == "None" ]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 5     891087950875897856                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# 24    887343217045368832                    NaN                  NaN
# 25    887101392804085760                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2342  666082916733198337                    NaN                  NaN
# 2343  666073100786774016                    NaN                  NaN
# 2344  666071193221509120                    NaN                  NaN
# 2351  666049248165822465                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 5     2017-07-29 00:08:17 +0000
# 7     2017-07-28 00:22:40 +0000
# 12    2017-07-25 01:55:32 +0000
# ...

# %%
test_name = archive_df[((archive_df.name.str.len() < 4) & (archive_df.name != 'None'))]
test_name.name.value_counts()
# Out:
# a      55
# Bo      9
# the     8
# an      7
# Jax     6
#        ..
# Ole     1
# Jay     1
# Ron     1
# Dot     1
# Jeb     1
# Name: name, Length: 68, dtype: int64

# %%
test_name[test_name.name == 'the']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1527  690360449368465409                    NaN                  NaN
# 1603  685943807276412928                    NaN                  NaN
# 1797  677269281705472000                    NaN                  NaN
# 1815  676613908052996102                    NaN                  NaN
# 2037  671561002136281088                    NaN                  NaN
# 2212  668587383441514497                    NaN                  NaN
# 2345  666063827256086533                    NaN                  NaN
# 2346  666058600524156928                    NaN                  NaN
#
#                       timestamp  \
# 1527  2016-01-22 02:28:52 +0000
# 1603  2016-01-09 21:58:42 +0000
# 1797  2015-12-16 23:29:14 +0000
# 1815  2015-12-15 04:05:01 +0000
# 2037  2015-12-01 05:26:34 +0000
# 2212  2015-11-23 00:30:28 +0000
# 2345  2015-11-16 01:22:45 +0000
# 2346  2015-11-16 01:01:59 +0000
#
# ...

# %%
test_name = archive_df[((archive_df.name.str.len() < 3) & (archive_df.name != 'None'))]
test_name.name.value_counts()
# Out:
# a     55
# Bo     9
# an     7
# Ed     1
# Al     1
# by     1
# my     1
# JD     1
# O      1
# Jo     1
# Mo     1
# Name: name, dtype: int64

# %%
test_name[test_name.name == 'an']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 759   778396591732486144                    NaN                  NaN
# 1025  746369468511756288                    NaN                  NaN
# 1362  703041949650034688                    NaN                  NaN
# 2204  668636665813057536                    NaN                  NaN
# 2333  666337882303524864                    NaN                  NaN
# 2335  666287406224695296                    NaN                  NaN
# 2349  666051853826850816                    NaN                  NaN
#
#                       timestamp  \
# 759   2016-09-21 00:53:04 +0000
# 1025  2016-06-24 15:48:42 +0000
# 1362  2016-02-26 02:20:37 +0000
# 2204  2015-11-23 03:46:18 +0000
# 2333  2015-11-16 19:31:45 +0000
# 2335  2015-11-16 16:11:11 +0000
# 2349  2015-11-16 00:35:11 +0000
#
#                                                  source  \
# 759   <a href="http://twitter.com/download/iphone" r...
# ...

# %%
test_name[test_name.name == 'a']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 56    881536004380872706                    NaN                  NaN
# 649   792913359805018113                    NaN                  NaN
# 801   772581559778025472                    NaN                  NaN
# 1002  747885874273214464                    NaN                  NaN
# 1004  747816857231626240                    NaN                  NaN
# 1017  746872823977771008                    NaN                  NaN
# 1049  743222593470234624                    NaN                  NaN
# 1193  717537687239008257                    NaN                  NaN
# 1207  715733265223708672                    NaN                  NaN
# 1340  704859558691414016                    NaN                  NaN
# 1351  704054845121142784                    NaN                  NaN
# 1361  703079050210877440                    NaN                  NaN
# 1368  702539513671897089                    NaN                  NaN
# ...

# %%
test_name[test_name.name == 'by']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1724  680085611152338944                    NaN                  NaN
#
#                       timestamp  \
# 1724  2015-12-24 18:00:19 +0000
#
#                                                  source  \
# 1724  <a href="https://about.twitter.com/products/tw...
#
#                                                    text  retweeted_status_id  \
# 1724  This is by far the most coordinated series of ...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1724                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1724  https://twitter.com/dog_rates/status/680085611...                12
#
#       rating_denominator name doggo floofer pupper puppo
# 1724                  10   by  None    None   None  None

# %%
test_name[test_name.name == 'my']
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 852  765395769549590528                    NaN                  NaN
#
#                      timestamp  \
# 852  2016-08-16 03:52:26 +0000
#
#                                                 source  \
# 852  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 852  This is my dog. Her name is Zoey. She knows I'...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 852                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 852  https://twitter.com/dog_rates/status/765395769...                13
#
#      rating_denominator name doggo floofer pupper puppo
# 852                  10   my  None    None   None  None

# %%
test_name[test_name.name == 'O']
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 775  776201521193218049                    NaN                  NaN
#
#                      timestamp  \
# 775  2016-09-14 23:30:38 +0000
#
#                                                 source  \
# 775  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 775  This is O'Malley. That is how he sleeps. Doesn...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 775                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 775  https://twitter.com/dog_rates/status/776201521...                10
#
#      rating_denominator name doggo floofer pupper puppo
# 775                  10    O  None    None   None  None

# %%
test_name[test_name.name == 'Al']
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 820  770414278348247044                    NaN                  NaN
#
#                      timestamp  \
# 820  2016-08-30 00:14:12 +0000
#
#                                                 source  \
# 820  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 820  Meet Al Cabone. He's a gangsta puppa. Rather h...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 820                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 820  https://twitter.com/dog_rates/status/770414278...                11
#
#      rating_denominator name doggo floofer pupper puppo
# 820                  10   Al  None    None   None  None

# %% [markdown]
# ### archive_df Quality Issues:
#
# - The none values in doggo, floofer, etc..
# - the tweets with wrong denomoniator assignment
# - the denominators that are not equal to 10
# - The none values in name column
# - Wrong name extractions
# - datatype for timestamp is not datetime
# - datatype for tweet_id is int
# - source column contains HTML tags
# - we only need original ratings and no retweets (only useful columns)

# %% [markdown]
# ## image_predictions quality assess

# %%
image_predictions.isna().sum()
# Out:
# tweet_id    0
# jpg_url     0
# img_num     0
# p1          0
# p1_conf     0
# p1_dog      0
# p2          0
# p2_conf     0
# p2_dog      0
# p3          0
# p3_conf     0
# p3_dog      0
# dtype: int64

# %%
image_predictions.duplicated().sum()
# Out:
# 0

# %%
image_predictions[image_predictions.p2_conf == image_predictions.p2_conf.min() ]
# Out:
#                tweet_id                                          jpg_url  \
# 106  667866724293877760  https://pbs.twimg.com/media/CUS9PlUWwAANeAD.jpg
#
#      img_num             p1  p1_conf  p1_dog          p2       p2_conf  \
# 106        1  jigsaw_puzzle      1.0   False  prayer_rug  1.011300e-08
#
#      p2_dog       p3       p3_conf  p3_dog
# 106   False  doormat  1.740170e-10   False

# %%
image_predictions[image_predictions['p1'] == image_predictions['p1'].str.title()]
# Out:
#                 tweet_id                                          jpg_url  \
# 15    666099513787052032  https://pbs.twimg.com/media/CT51-JJUEAA6hV8.jpg
# 27    666396247373291520  https://pbs.twimg.com/media/CT-D2ZHWIAA3gK1.jpg
# 32    666428276349472768  https://pbs.twimg.com/media/CT-g-0DUwAEQdSn.jpg
# 35    666437273139982337  https://pbs.twimg.com/media/CT-pKmRWIAAxUWj.jpg
# 49    666835007768551424  https://pbs.twimg.com/media/CUES51dXIAEahyG.jpg
# ...                  ...                                              ...
# 2065  890240255349198849  https://pbs.twimg.com/media/DFrEyVuW0AAO3t9.jpg
# 2067  890729181411237888  https://pbs.twimg.com/media/DFyBahAVwAAhUTd.jpg
# 2068  890971913173991426  https://pbs.twimg.com/media/DF1eOmZXUAALUcq.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
#
#       img_num           p1   p1_conf  p1_dog             p2   p2_conf  p2_dog  \
# ...

# %%
image_predictions[image_predictions['p2'] == image_predictions['p2'].str.title()]
# Out:
#                 tweet_id                                          jpg_url  \
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 15    666099513787052032  https://pbs.twimg.com/media/CT51-JJUEAA6hV8.jpg
# 16    666102155909144576  https://pbs.twimg.com/media/CT54YGiWUAEZnoK.jpg
# 22    666337882303524864  https://pbs.twimg.com/media/CT9OwFIWEAMuRje.jpg
# 38    666644823164719104  https://pbs.twimg.com/media/CUBl6IwVAAA9_zT.jpg
# ...                  ...                                              ...
# 2047  886736880519319552  https://pbs.twimg.com/media/DE5Se8FXcAAJFx4.jpg
# 2062  889665388333682689  https://pbs.twimg.com/media/DFi579UWsAAatzw.jpg
# 2064  890006608113172480  https://pbs.twimg.com/media/DFnwSY4WAAAMliS.jpg
# 2065  890240255349198849  https://pbs.twimg.com/media/DFrEyVuW0AAO3t9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
#
#       img_num                  p1   p1_conf  p1_dog              p2   p2_conf  \
# ...

# %%
image_predictions[image_predictions['p3'] == image_predictions['p3'].str.title()]
# Out:
#                 tweet_id                                            jpg_url  \
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 11    666071193221509120    https://pbs.twimg.com/media/CT5cN_3WEAAlOoZ.jpg
# 15    666099513787052032    https://pbs.twimg.com/media/CT51-JJUEAA6hV8.jpg
# 30    666418789513326592    https://pbs.twimg.com/media/CT-YWb7U8AA7QnN.jpg
# 31    666421158376562688    https://pbs.twimg.com/media/CT-aggCXAAIMfT3.jpg
# ...                  ...                                                ...
# 2050  887343217045368832  https://pbs.twimg.com/ext_tw_video_thumb/88734...
# 2053  887705289381826560    https://pbs.twimg.com/media/DFHDQBbXgAEqY7t.jpg
# 2059  889278841981685760  https://pbs.twimg.com/ext_tw_video_thumb/88927...
# 2065  890240255349198849    https://pbs.twimg.com/media/DFrEyVuW0AAO3t9.jpg
# 2067  890729181411237888    https://pbs.twimg.com/media/DFyBahAVwAAhUTd.jpg
#
# ...

# %% [markdown]
# ## image_predictions Quality issues:
# - tweets that has no image in this dataframe
# - predictions that has underscores and dashes and uppercase letters
# - non-descriptive column names (p,p1,p1_dog)

# %% [markdown]
# ### api_df quality issues

# %%
api_df
# Out:
#                 tweet_id  retweet_count  favorite_count
# 0     892420643555336193           7489           35461
# 1     892177421306343426           5557           30693
# 2     891815181378084864           3681           23088
# 3     891689557279858688           7665           38754
# 4     891327558926688256           8267           37032
# ...                  ...            ...             ...
# 2326  666049248165822465             40              96
# 2327  666044226329800704            125             264
# 2328  666033412701032449             39             109
# 2329  666029285002620928             41             119
# 2330  666020888022790149            454            2357
#
# [2331 rows x 3 columns]

# %% [markdown]
# api_df issues:
# - number of entries are less than that of archive_df

# %% [markdown]
# # Cleaning

# %% [markdown]
# ## archive_df Tidiness
#
# ### Define

# %% [markdown]
# - melt columns doggo, pupper etc into one column dog_breed
# - drop the columns unrelated to our project
#
# N.B: I also dropped the unrelated rows to filter out non-original tweets although this is a quality issue)

# %% [markdown]
# ### Code

# %%
archive_copy = archive_df.copy()
archive_copy.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %%
#melt the dog breeds columns into one column

columns_list = ['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
       'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
       'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
       'rating_denominator', 'name']

var = ['doggo', 'floofer', 'pupper', 'puppo']

archive_copy = pd.melt(archive_copy, id_vars = columns_list, value_vars = var, value_name= 'dog_stage')

#drop the variable column

archive_copy.drop('variable',axis=1, inplace=True)

# %%
# drop the rows where in_reply_to_status and retweeted_status is not null to only keep original tweets
archive_copy = archive_copy[archive_copy.in_reply_to_status_id.isnull() & archive_copy.retweeted_status_id.isnull()]

# %%
# Then drop these columns as we will not need it
unrelated_cols = ['in_reply_to_status_id', 'in_reply_to_user_id','retweeted_status_id', 'retweeted_status_user_id',
       'retweeted_status_timestamp']

archive_copy.drop(unrelated_cols, axis=1, inplace=True)

# %% [markdown]
# ### Test

# %%
archive_copy
# Out:
#                 tweet_id                  timestamp  \
# 0     892420643555336193  2017-08-01 16:23:56 +0000
# 1     892177421306343426  2017-08-01 00:17:27 +0000
# 2     891815181378084864  2017-07-31 00:18:03 +0000
# 3     891689557279858688  2017-07-30 15:58:51 +0000
# 4     891327558926688256  2017-07-29 16:00:24 +0000
# ...                  ...                        ...
# 9419  666049248165822465  2015-11-16 00:24:50 +0000
# 9420  666044226329800704  2015-11-16 00:04:52 +0000
# 9421  666033412701032449  2015-11-15 23:21:54 +0000
# 9422  666029285002620928  2015-11-15 23:05:30 +0000
# 9423  666020888022790149  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# ...

# %%
archive_copy.dog_stage.value_counts()
# Out:
# None       8041
# pupper      230
# doggo        83
# puppo        24
# floofer      10
# Name: dog_stage, dtype: int64

# %% [markdown]
# ## image_predictions Tidiness
#
# ## Define
#
# - melt the p, p_conf and p_dog columns
# - merge the image_predictions df with the archive_df into a master df

# %% [markdown]
# ## Code

# %%
image_copy = image_predictions.copy()

cols = ['tweet_id', 'jpg_url', 'img_num', 
       'prediction_1', 'confidence_1', 'breed_1',
       'prediction_2', 'confidence_2', 'breed_2',
       'prediction_3', 'confidence_3', 'breed_3']

image_copy.columns = cols

# Reshaping the dataframe
image_copy = pd.wide_to_long(image_copy, stubnames=['prediction', 'confidence', 'breed'], 
    i=['tweet_id', 'jpg_url', 'img_num'], j='prediction_level', sep="_").reset_index()

# %%
master_df = archive_copy.merge(image_copy, on='tweet_id')

# %% [markdown]
# ### Test

# %%
image_copy
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 2     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 3     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 4     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# ...                  ...                                              ...
# 6220  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 6221  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 6222  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
# 6223  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
# 6224  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num  prediction_level              prediction  confidence  breed
# ...

# %%
master_df
# Out:
#                  tweet_id                  timestamp  \
# 0      892420643555336193  2017-08-01 16:23:56 +0000
# 1      892420643555336193  2017-08-01 16:23:56 +0000
# 2      892420643555336193  2017-08-01 16:23:56 +0000
# 3      892420643555336193  2017-08-01 16:23:56 +0000
# 4      892420643555336193  2017-08-01 16:23:56 +0000
# ...                   ...                        ...
# 23647  666020888022790149  2015-11-15 22:32:08 +0000
# 23648  666020888022790149  2015-11-15 22:32:08 +0000
# 23649  666020888022790149  2015-11-15 22:32:08 +0000
# 23650  666020888022790149  2015-11-15 22:32:08 +0000
# 23651  666020888022790149  2015-11-15 22:32:08 +0000
#
#                                                   source  \
# 0      <a href="http://twitter.com/download/iphone" r...
# 1      <a href="http://twitter.com/download/iphone" r...
# 2      <a href="http://twitter.com/download/iphone" r...
# 3      <a href="http://twitter.com/download/iphone" r...
# ...

# %% [markdown]
# ## api_df Tidiness
#
# ### Define
#
# - merge with archive_df

# %%
api_copy = api_df.copy()

# %% [markdown]
# ### Code

# %%
api_copy
master_df = master_df.merge(api_copy, on='tweet_id')

# %% [markdown]
# ### Test

# %%
master_df
# Out:
#                  tweet_id                  timestamp  \
# 0      892420643555336193  2017-08-01 16:23:56 +0000
# 1      892420643555336193  2017-08-01 16:23:56 +0000
# 2      892420643555336193  2017-08-01 16:23:56 +0000
# 3      892420643555336193  2017-08-01 16:23:56 +0000
# 4      892420643555336193  2017-08-01 16:23:56 +0000
# ...                   ...                        ...
# 23563  666020888022790149  2015-11-15 22:32:08 +0000
# 23564  666020888022790149  2015-11-15 22:32:08 +0000
# 23565  666020888022790149  2015-11-15 22:32:08 +0000
# 23566  666020888022790149  2015-11-15 22:32:08 +0000
# 23567  666020888022790149  2015-11-15 22:32:08 +0000
#
#                                                   source  \
# 0      <a href="http://twitter.com/download/iphone" r...
# 1      <a href="http://twitter.com/download/iphone" r...
# 2      <a href="http://twitter.com/download/iphone" r...
# 3      <a href="http://twitter.com/download/iphone" r...
# ...

# %% [markdown]
# # master_df Quality issues
#
# ## Define
#
# - replace none values in dog_stage to nans
# - replace none values in name with nan
# - fix meaningless name values by extracting the correct names from text
# - change datatype for timestamp to datetime
# - change tweet_id dtype to string
# - fix the tweets with wrong numerator assignment
# - fix the tweets with wrong denominator assignment (that are mentioned otherwise or ommitted in the tweet text)
# - make all other denominators equal to 10
# - remove HTML tags in source column
# - we only need original ratings and no retweets (done in tidiness)
#
# - tweets that has no image in this dataframe
# - predictions that has underscores and dashes and uppercase letters

# %% [markdown]
# ### Code

# %%
master_df = master_df.loc[master_df["prediction_level"] == 1]

# %%
master_df.loc[:, 'name'] = master_df.loc[:, 'name'].replace('None',np.nan)

# %%
master_df.loc[:, 'dog_stage'] = master_df.loc[:, 'dog_stage'].replace('None',np.nan)

# %%
master_df[(master_df['name'].str.len() < 3) & (master_df['name'] != '')]
# Out:
#                  tweet_id                  timestamp  \
# 588    881536004380872706  2017-07-02 15:32:16 +0000
# 591    881536004380872706  2017-07-02 15:32:16 +0000
# 594    881536004380872706  2017-07-02 15:32:16 +0000
# 597    881536004380872706  2017-07-02 15:32:16 +0000
# 3456   825876512159186944  2017-01-30 01:21:19 +0000
# ...                   ...                        ...
# 23541  666033412701032449  2015-11-15 23:21:54 +0000
# 23544  666029285002620928  2015-11-15 23:05:30 +0000
# 23547  666029285002620928  2015-11-15 23:05:30 +0000
# 23550  666029285002620928  2015-11-15 23:05:30 +0000
# 23553  666029285002620928  2015-11-15 23:05:30 +0000
#
#                                                   source  \
# 588    <a href="http://twitter.com/download/iphone" r...
# 591    <a href="http://twitter.com/download/iphone" r...
# 594    <a href="http://twitter.com/download/iphone" r...
# 597    <a href="http://twitter.com/download/iphone" r...
# ...

# %%
pattern = re.compile(r'(?:name(?:d)?)\s{1}(?:is\s)?([A-Za-z]+)')

for index, row in master_df.iterrows():  
    try:
        if row['name'] == "a":
            clean_name = re.findall(pattern, row['text'])[0]
            master_df.loc[index,'name'] = master_df.loc[index,'name'].replace('a', clean_name)
        elif row['name'] == 'an':
            clean_name = re.findall(pattern, row['text'])[0]
            master_df.loc[index,'name'] = master_df.loc[index,'name'].replace('an', clean_name)
        elif row['name'] == 'the':
            clean_name = re.findall(pattern, row['text'])[0]
            master_df.loc[index,'name'] = master_df.loc[index, 'name'].replace('the', clean_name)
        elif row['name'] == 'by':
            clean_name = re.findall(pattern, row['text'])[0]
            master_df.loc[index,'name'] = master_df.loc[index, 'name'].replace('by', clean_name)
        elif row['name'] == 'O':
            clean_name = re.findall(pattern, row['text'])[0]
            master_df.loc[index,'name'] = master_df.loc[index, 'name'].replace('O', clean_name)
        elif row['name'] == 'Al':
            clean_name = re.findall(pattern, row['text'])[0]
            master_df.loc[index,'name'] = master_df.loc[index, 'name'].replace('Al', clean_name)
        elif row['name'] == 'my':
            clean_name = re.findall(pattern, row['text'])[0]
            master_df.loc[index,'name'] = master_df.loc[index, 'name'].replace('my', clean_name)

    except IndexError:
        master_df.loc[index,'name'] = np.nan

# %%
master_df.duplicated().sum()
# Out:
# 5580

# %%
master_df.drop_duplicates(inplace=True)

# %%
master_df.timestamp = pd.to_datetime(master_df['timestamp'])

# %%
master_df.tweet_id = master_df.tweet_id.astype(str)

# %%
for index, row in master_df.iterrows():
    if row['rating_denominator'] != 10:
        master_df.loc[index, 'rating_denominator'] = 10

# %%
master_df[master_df.rating_denominator > 10]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, expanded_urls, rating_numerator, rating_denominator, name, dog_stage, jpg_url, img_num, prediction_level, prediction, confidence, breed, retweet_count, favorite_count]
# Index: []

# %%
master_df[master_df.rating_denominator < 10]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, expanded_urls, rating_numerator, rating_denominator, name, dog_stage, jpg_url, img_num, prediction_level, prediction, confidence, breed, retweet_count, favorite_count]
# Index: []

# %%
master_df.rating_denominator = master_df.rating_denominator.replace(np.nan, '')

# %%
master_df.rating_numerator = master_df.rating_numerator.replace(np.nan, '')

# %%
master_df['prediction'] = master_df['prediction'].str.lower().str.replace('_', ' ').str.replace('-',' ')

# %%
master_df.source = master_df.source.str.replace(r'<(?:a\b[^>]*>|/a>)', '')

# %% [markdown]
# ## Test

# %%
master_df.dog_stage.unique()
# Out:
# array([nan, 'doggo', 'puppo', 'pupper', 'floofer'], dtype=object)

# %%
master_df[(master_df['name'].str.len() < 3) & (master_df['name'] != '')]
# Out:
#                  tweet_id                 timestamp              source  \
# 3456   825876512159186944 2017-01-30 01:21:19+00:00  Twitter for iPhone
# 3912   819004803107983360 2017-01-11 02:15:36+00:00  Twitter for iPhone
# 3915   819004803107983360 2017-01-11 02:15:36+00:00  Twitter for iPhone
# 4848   804026241225523202 2016-11-30 18:16:08+00:00  Twitter for iPhone
# 5796   789137962068021249 2016-10-20 16:15:26+00:00  Twitter for iPhone
# 7596   761004547850530816 2016-08-04 01:03:17+00:00  Twitter for iPhone
# 8580   749996283729883136 2016-07-04 16:00:22+00:00           TweetDeck
# 15912  681694085539872773 2015-12-29 04:31:49+00:00  Twitter for iPhone
# 15918  681694085539872773 2015-12-29 04:31:49+00:00  Twitter for iPhone
# 19260  672834301050937345 2015-12-04 17:46:12+00:00  Twitter for iPhone
# 19872  671542985629241344 2015-12-01 04:14:59+00:00  Twitter for iPhone
# 21960  668496999348633600 2015-11-22 18:31:19+00:00  Twitter for iPhone
#
# ...

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2276 entries, 0 to 23556
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2276 non-null   object
#  1   timestamp           2276 non-null   datetime64[ns, UTC]
#  2   source              2276 non-null   object
#  3   text                2276 non-null   object
#  4   expanded_urls       2276 non-null   object
#  5   rating_numerator    2276 non-null   int64
#  6   rating_denominator  2276 non-null   int64
#  7   name                1577 non-null   object
#  8   dog_stage           312 non-null    object
#  9   jpg_url             2276 non-null   object
#  10  img_num             2276 non-null   int64
#  11  prediction_level    2276 non-null   int64
#  12  prediction          2276 non-null   object
#  13  confidence          2276 non-null   float64
#  14  breed               2276 non-null   bool
# ...

# %%
master_df.rating_denominator.unique()
# Out:
# array([10], dtype=int64)

# %%
master_df.rating_numerator.value_counts()
# Out:
# 12      521
# 10      474
# 11      462
# 13      295
# 9       167
# 8       110
# 7        60
# 14       48
# 5        36
# 6        33
# 3        20
# 4        16
# 2         9
# 1         5
# 27        2
# 24        1
# 26        1
# 165       1
# 50        1
# 44        1
# 144       1
# 60        1
# 80        1
# 84        1
# 88        1
# 121       1
# 204       1
# 420       1
# 1776      1
# 45        1
# 75        1
# 99        1
# 0         1
# Name: rating_numerator, dtype: int64

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2276 entries, 0 to 23556
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2276 non-null   object
#  1   timestamp           2276 non-null   datetime64[ns, UTC]
#  2   source              2276 non-null   object
#  3   text                2276 non-null   object
#  4   expanded_urls       2276 non-null   object
#  5   rating_numerator    2276 non-null   int64
#  6   rating_denominator  2276 non-null   int64
#  7   name                1577 non-null   object
#  8   dog_stage           312 non-null    object
#  9   jpg_url             2276 non-null   object
#  10  img_num             2276 non-null   int64
#  11  prediction_level    2276 non-null   int64
#  12  prediction          2276 non-null   object
#  13  confidence          2276 non-null   float64
#  14  breed               2276 non-null   bool
# ...

# %%
master_df.source
# Out:
# 0        Twitter for iPhone
# 12       Twitter for iPhone
# 24       Twitter for iPhone
# 36       Twitter for iPhone
# 48       Twitter for iPhone
#                 ...
# 23508    Twitter for iPhone
# 23520    Twitter for iPhone
# 23532    Twitter for iPhone
# 23544    Twitter for iPhone
# 23556    Twitter for iPhone
# Name: source, Length: 2276, dtype: object

# %%
sum(master_df.prediction.str.contains('_'))
# Out:
# 0

# %%
sum(master_df.prediction.str.contains('-'))
# Out:
# 0

# %% [markdown]
# ### Define:
# - remove unnecassry columns

# %% [markdown]
# ### Code

# %%
master_df
# Out:
#                  tweet_id                 timestamp              source  \
# 0      892420643555336193 2017-08-01 16:23:56+00:00  Twitter for iPhone
# 12     892177421306343426 2017-08-01 00:17:27+00:00  Twitter for iPhone
# 24     891815181378084864 2017-07-31 00:18:03+00:00  Twitter for iPhone
# 36     891689557279858688 2017-07-30 15:58:51+00:00  Twitter for iPhone
# 48     891327558926688256 2017-07-29 16:00:24+00:00  Twitter for iPhone
# ...                   ...                       ...                 ...
# 23508  666049248165822465 2015-11-16 00:24:50+00:00  Twitter for iPhone
# 23520  666044226329800704 2015-11-16 00:04:52+00:00  Twitter for iPhone
# 23532  666033412701032449 2015-11-15 23:21:54+00:00  Twitter for iPhone
# 23544  666029285002620928 2015-11-15 23:05:30+00:00  Twitter for iPhone
# 23556  666020888022790149 2015-11-15 22:32:08+00:00  Twitter for iPhone
#
#                                                     text  \
# ...

# %%
master_df = master_df.drop(['source', 'text', 'img_num', 'prediction_level', 'expanded_urls'], axis=1)

# %% [markdown]
# ### Test

# %%
master_df
# Out:
#                  tweet_id                 timestamp  rating_numerator  \
# 0      892420643555336193 2017-08-01 16:23:56+00:00                13
# 12     892177421306343426 2017-08-01 00:17:27+00:00                13
# 24     891815181378084864 2017-07-31 00:18:03+00:00                12
# 36     891689557279858688 2017-07-30 15:58:51+00:00                13
# 48     891327558926688256 2017-07-29 16:00:24+00:00                12
# ...                   ...                       ...               ...
# 23508  666049248165822465 2015-11-16 00:24:50+00:00                 5
# 23520  666044226329800704 2015-11-16 00:04:52+00:00                 6
# 23532  666033412701032449 2015-11-15 23:21:54+00:00                 9
# 23544  666029285002620928 2015-11-15 23:05:30+00:00                 7
# 23556  666020888022790149 2015-11-15 22:32:08+00:00                 8
#
#        rating_denominator      name dog_stage  \
# 0                      10   Phineas       NaN
# ...

# %% [markdown]
# # Storing

# %%
master_df.to_csv('Twitter_archive_master.csv')

# %%
image_copy.to_csv('Image_predictions.csv')

# %%
api_df.to_csv('tweepy-data.csv')

# %% [markdown]
# # Analysis & Visualizations

# %% [markdown]
# We can now use our data to deduce many insights, such as:
# - The growth of retweets and favorite counts for the tweets over time
# - Which dog breed receives the highest favorite counts and retweet counts?
# - What dog stage receives the highest favorite counts and retweet counts?

# %%
# Growth of retweets and favorite count over time
pop_growth = master_df.groupby(master_df['timestamp'].dt.strftime('%Y-%m'))[['retweet_count','favorite_count']].sum().sort_index()
pop_growth
# Out:
#            retweet_count  favorite_count
# timestamp
# 2015-11           139822          340248
# 2015-12           537792         1338783
# 2016-01           271838          747397
# 2016-02           170802          489071
# 2016-03           187356          548438
# 2016-04            88421          274168
# 2016-05           160706          485731
# 2016-06           467710         1125956
# 2016-07           239611          715450
# 2016-08           195963          583089
# 2016-09           249926          785191
# 2016-10           265687          864893
# 2016-11           284642          873749
# 2016-12           286667          923160
# 2017-01           539373         1664730
# 2017-02           286915         1281311
# 2017-03           213787          952377
# 2017-04           254926         1019159
# 2017-05           327636         1329932
# 2017-06           276003         1297491
# 2017-07           337132         1652911
# ...

# %%
# visualization of the above data
pop_growth.plot();
plt.savefig('popularity growth')

# %% [markdown]
# We can notice how both retweets and favorites had their peaks and troughs through time. Having the peak of favorites near January 2017 and that both have decreaed greatly at the second half of 2017

# %%
# Dog breeds with highest favorite counts and retweet counts (Top 5)
pop_dogs = master_df.groupby(master_df['prediction'])[['retweet_count','favorite_count']].sum().sort_values(by=['retweet_count','favorite_count'], ascending=False)
pop_dogs
# Out:
#                     retweet_count  favorite_count
# prediction
# golden retriever           573869         2019146
# labrador retriever         414662         1263874
# pembroke                   292353         1073759
# chihuahua                  215752          690346
# samoyed                    189682          567262
# ...                           ...             ...
# piggy bank                     76             305
# pitcher                        74             340
# platypus                       60             310
# crash helmet                   36             185
# desktop computer               32              94
#
# [373 rows x 2 columns]

# %%
# Now plot the most popular dog breeds
plot = pop_dogs.head(5).plot(kind='bar', figsize=(8,8), title = 'Most Popular Dog Breeds')
plot.set_xlabel("Dog Breed")
plot.set_ylabel("Retweets and Favorite Count");
plt.xticks(rotation=0)
plt.savefig('popular breeds')

# %% [markdown]
# We can deduce that the most popular dog breeds are respectively: Golden Retriever, Labs, Pembroke, Chihuahua, Samoyed.

# %%
# Now we are gonna get the most popular dog stages
pop_stage = master_df.groupby(master_df['dog_stage'])[['retweet_count','favorite_count']].sum().sort_values(by=['retweet_count','favorite_count'], ascending=False)
pop_stage
# Out:
#            retweet_count  favorite_count
# dog_stage
# doggo             446393         1313220
# pupper            444759         1429295
# puppo             141826          495565
# floofer            32659           98206

# %%
plot = pop_stage.plot(kind='bar', figsize=(8,8), title = 'Most Popular Dog Stage')
plot.set_xlabel("Dog Stage")
plot.set_ylabel("Retweets and Favorite Count");
plt.xticks(rotation=0)
plt.savefig('popular stage')

# %% [markdown]
# So the most popular dog stage is puuper and the least is floofer
